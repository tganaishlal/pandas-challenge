# %%
# create dependencies
import pandas as pd
import numpy as np

# load files
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read Student Data File and create the pd data frame
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data 
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#calculate the total number of schools
total_schools=school_data["school_name"].count()
total_schools

#calculate the total number of students
total_students=student_data["student_name"].count()
total_students

#calculate the total budget
total_budget=school_data["budget"].sum()
total_budget

#calculate the average math score
avg_math=student_data[("math_score")].mean()
avg_math

#calculate the average reading score
avg_reading=student_data[("reading_score")].mean()
avg_reading

#calculate the passing rate 
overall_avg=((avg_math + avg_reading) /2)
overall_avg

#calculate the percentage of students with a passing math score (70 or greater)
perc_math_pass=(school_data_complete["math_score"]>70).sum() / school_data_complete["math_score"].count()* 100
perc_math_pass 

#calculate the percentage of students with a passing reading score (70 or greater)
perc_reading_pass= (school_data_complete["reading_score"]>70).sum() / school_data_complete["reading_score"].count()* 100
perc_reading_pass
# Out:
# 82.97166198621395

# %%
# create the district 
District_Summary = pd.DataFrame({"Total Schools":[total_schools], "Total Students":[total_students],"Total Budget":[total_budget],
                                "Average Math Score":[avg_math], "Average Reading Score":[avg_reading], "% Passing Math":[perc_math_pass],
                                "% Passing Reading":[perc_reading_pass],"% overall Passing Rate":[overall_avg]})
District_Summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       72.392137          82.971662
#
#    % overall Passing Rate
# 0               80.431606

# %%
#create a new data frame for district Summery to do mapping
District_Summary_DF=pd.DataFrame(District_Summary, columns=["Total Schools","Total Students","Total Budget",
                                                           "Average Math Score","Average Reading Score","% Passing Math","% Passing Reading",
                                                          "% Overall Passing Rate"])
District_Summary_DF
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       72.392137          82.971662
#
#    % Overall Passing Rate
# 0                     NaN

# %%
#map the District data frame from the prior df

District_Summary_DF["Total Students"]=District_Summary_DF["Total Students"].map("{:,}".format)
District_Summary_DF["Total Budget"]=District_Summary_DF["Total Budget"].map("{:,}".format)


District_Summary_DF["Average Math Score"]=District_Summary_DF["Average Math Score"].map("{:,.2f}".format)

District_Summary_DF
# Out:
#    Total Schools Total Students Total Budget Average Math Score  \
# 0             15         39,170   24,649,428              78.99
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       72.392137          82.971662
#
#    % Overall Passing Rate
# 0                     NaN

# %%
#create the school count variabele
sch_count= len(school_data_complete["school_name"].unique())
sch_count
# Out:
# 15

# %%
#School Name
sch_types=school_data.set_index(["school_name"])["type"]

# %%
#sum of all students in each school
stu_per_sch=school_data_complete["school_name"].value_counts()
stu_per_sch.head()
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Name: school_name, dtype: int64

# %%
#School Budget variable
sch_budget=school_data_complete.groupby(["school_name"])["budget"].mean()
sch_budget.head()
# Out:
# school_name
# Bailey High School      3124928.0
# Cabrera High School     1081356.0
# Figueroa High School    1884411.0
# Ford High School        1763916.0
# Griffin High School      917500.0
# Name: budget, dtype: float64

# %%
#create the student budget variable
per_stu_bud=sch_budget/stu_per_sch
per_stu_bud
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#whats the average math score per school
avg_math_perSch=school_data_complete.groupby(["school_name"])["math_score"].mean()
avg_math_perSch.head()
# Out:
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Ford High School        77.102592
# Griffin High School     83.351499
# Name: math_score, dtype: float64

# %%
#what is the average reading score 
avg_red_perSch= school_data_complete.groupby(["school_name"])["reading_score"].mean()
avg_red_perSch.head()
# Out:
# school_name
# Bailey High School      81.033963
# Cabrera High School     83.975780
# Figueroa High School    81.158020
# Ford High School        80.746258
# Griffin High School     83.816757
# Name: reading_score, dtype: float64

# %%
#% of the passing math score 
pas_math_scor=school_data_complete.loc[school_data_complete["math_score"]>=70]
pas_math_scor

#create a variable assigning the math scoore by each school
group_math_sch=pas_math_scor["school_name"].value_counts()
group_math_sch.head()

percent_math=group_math_sch/stu_per_sch*100
percent_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: school_name, dtype: float64

# %%
#% passing Reading per school
read_scor=school_data_complete.loc[school_data_complete["reading_score"]>=70]

#creating a varaible for the reading score by each school
by_read_PerSch= read_scor["school_name"].value_counts()
by_read_PerSch.head()

#variable for percentage result
percent_read=by_read_PerSch/stu_per_sch*100
percent_read
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: school_name, dtype: float64

# %%
school_summery_df = pd.DataFrame({"School Type":sch_types, "Total Students":stu_per_sch, "Total School Budget":sch_budget
                                ,"Per Student Budget":per_stu_bud ,"Average Math Score" :avg_math_perSch,
                             "Average Reading Score":avg_red_perSch,
                             "% Passing Math":percent_math, "% Passing Reading":percent_read,
                            "% Overall Passing Rate":'overall'})

# %%
school_summery_df.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976            3124928.0
# Cabrera High School      Charter            1858            1081356.0
# Figueroa High School    District            2949            1884411.0
# Ford High School        District            2739            1763916.0
# Griffin High School      Charter            1468             917500.0
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# Figueroa High School              81.158020       65.988471
# Ford High School                  80.746258       68.309602
# Griffin High School               83.816757       93.392371
#
#                       % Passing Reading % Overall Passing Rate
# Bailey High School            81.933280                overall
# Cabrera High School           97.039828                overall
# Figueroa High School          80.739234                overall
# Ford High School              79.299014                overall
# Griffin High School           97.138965                overall

# %%
#top school based on passing rate
TopSch_df=school_summery_df.sort_values(["% Passing Math","% Passing Reading","% Overall Passing Rate"], 
                                        ascending=False)

# %%
TopSch_df.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Pena High School        Charter             962             585858.0
# Cabrera High School     Charter            1858            1081356.0
# Wilson High School      Charter            2283            1319574.0
# Shelton High School     Charter            1761            1056600.0
# Griffin High School     Charter            1468             917500.0
#
#                      Per Student Budget  Average Math Score  \
# Pena High School                  609.0           83.839917
# Cabrera High School               582.0           83.061895
# Wilson High School                578.0           83.274201
# Shelton High School               600.0           83.359455
# Griffin High School               625.0           83.351499
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Pena High School                 84.044699       94.594595          95.945946
# Cabrera High School              83.975780       94.133477          97.039828
# Wilson High School               83.989488       93.867718          96.539641
# Shelton High School              83.725724       93.867121          95.854628
# Griffin High School              83.816757       93.392371          97.138965
#
#                     % Overall Passing Rate
# Pena High School                   overall
# Cabrera High School                overall
# Wilson High School                 overall
# Shelton High School                overall
# Griffin High School                overall

# %%
#create a mapping that links the top schools by the passing rate
TopSch_df["Total School Budget"]=TopSch_df["Total School Budget"].map("${:,.2f}".format)
TopSch_df["Per Student Budget"]=TopSch_df["Per Student Budget"].map("${:,.2f}".format)

TopSch_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Pena High School          Charter             962         $585,858.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Wilson High School        Charter            2283       $1,319,574.00
# Shelton High School       Charter            1761       $1,056,600.00
# Griffin High School       Charter            1468         $917,500.00
# Wright High School        Charter            1800       $1,049,400.00
# Thomas High School        Charter            1635       $1,043,130.00
# Holden High School        Charter             427         $248,087.00
# Ford High School         District            2739       $1,763,916.00
# Hernandez High School    District            4635       $3,022,020.00
# Bailey High School       District            4976       $3,124,928.00
# Rodriguez High School    District            3999       $2,547,363.00
# Johnson High School      District            4761       $3,094,650.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
#
#                       Per Student Budget  Average Math Score  \
# Pena High School                 $609.00           83.839917
# Cabrera High School              $582.00           83.061895
# Wilson High School               $578.00           83.274201
# Shelton High School              $600.00           83.359455
# Griffin High School              $625.00           83.351499
# Wright High School               $583.00           83.682222
# Thomas High School               $638.00           83.418349
# Holden High School               $581.00           83.803279
# Ford High School                 $644.00           77.102592
# Hernandez High School            $652.00           77.289752
# Bailey High School               $628.00           77.048432
# Rodriguez High School            $637.00           76.842711
# Johnson High School              $650.00           77.072464
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
#
#                        Average Reading Score  % Passing Math  \
# Pena High School                   84.044699       94.594595
# Cabrera High School                83.975780       94.133477
# Wilson High School                 83.989488       93.867718
# Shelton High School                83.725724       93.867121
# Griffin High School                83.816757       93.392371
# Wright High School                 83.955000       93.333333
# Thomas High School                 83.848930       93.272171
# Holden High School                 83.814988       92.505855
# Ford High School                   80.746258       68.309602
# Hernandez High School              80.934412       66.752967
# Bailey High School                 81.033963       66.680064
# Rodriguez High School              80.744686       66.366592
# Johnson High School                80.966394       66.057551
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
#
#                        % Passing Reading % Overall Passing Rate
# Pena High School               95.945946                overall
# Cabrera High School            97.039828                overall
# Wilson High School             96.539641                overall
# Shelton High School            95.854628                overall
# Griffin High School            97.138965                overall
# Wright High School             96.611111                overall
# Thomas High School             97.308869                overall
# Holden High School             96.252927                overall
# Ford High School               79.299014                overall
# Hernandez High School          80.862999                overall
# Bailey High School             81.933280                overall
# Rodriguez High School          80.220055                overall
# Johnson High School            81.222432                overall
# Figueroa High School           80.739234                overall
# Huang High School              81.316421                overall

# %%
#sort the top five worst performing schools
BottomSch_df=school_summery_df.sort_values("% Overall Passing Rate")
BottomSch_df.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976            3124928.0
# Cabrera High School      Charter            1858            1081356.0
# Figueroa High School    District            2949            1884411.0
# Ford High School        District            2739            1763916.0
# Griffin High School      Charter            1468             917500.0
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# Figueroa High School              81.158020       65.988471
# Ford High School                  80.746258       68.309602
# Griffin High School               83.816757       93.392371
#
#                       % Passing Reading % Overall Passing Rate
# Bailey High School            81.933280                overall
# Cabrera High School           97.039828                overall
# Figueroa High School          80.739234                overall
# Ford High School              79.299014                overall
# Griffin High School           97.138965                overall

# %%
#creating a table which list the math score for the grade levels
math_9th=student_data.loc[student_data["grade"] == "9th"].groupby(["school_name"])['math_score'].mean()
math_9th.head()
math_10th=student_data.loc[student_data["grade"] == "10th"].groupby(["school_name"])['math_score'].mean()
math_10th.head()
math_11th=student_data.loc[student_data["grade"] == "11th"].groupby(["school_name"])["math_score"].mean()
math_11th.head()
math_12th=student_data.loc[student_data["grade"] == "12th"].groupby(["school_name"])["math_score"].mean()
math_12th.head()

#create a date frame for math score by grade level
math_byGrad=pd.DataFrame({"9th":math_9th, "10th": math_10th, "11th":math_11th, "12th":math_12th })
math_byGrad
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %%
#create the same table we did above but for the reading scores
read_9th=student_data.loc[student_data["grade"] == "9th" ].groupby(["school_name"])["reading_score"].mean()
read_10th=student_data.loc[student_data["grade"] == "10th" ].groupby(["school_name"])["reading_score"].mean()
read_11th=student_data.loc[student_data["grade"] == "11th" ].groupby(["school_name"])["reading_score"].mean()
read_12th=student_data.loc[student_data["grade"] == "12th" ].groupby(["school_name"])["reading_score"].mean()

# %%
reading_byGrade=pd.DataFrame({"9th":read_9th,"10th":read_10th, "11th":read_11th, "12th":read_12th })
reading_byGrade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %%
#creating a new dataframe based on school spending and use test scores 

bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
school_summery_df["Spending Ranges (Per Student)"]=pd.cut(school_summery_df["Total School Budget"]/school_summery_df["Total Students"]
                                            ,bins , labels=group_names)
school_summery_df.head()
scores_by_sch=school_summery_df .drop(columns=["Total Students", "Total School Budget","School Type", "Per Student Budget"])
scores_by_sch
# Out:
#                        Average Math Score  Average Reading Score  \
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# Wilson High School              83.274201              83.989488
# Wright High School              83.682222              83.955000
#
#                        % Passing Math  % Passing Reading  \
# Bailey High School          66.680064          81.933280
# Cabrera High School         94.133477          97.039828
# Figueroa High School        65.988471          80.739234
# Ford High School            68.309602          79.299014
# Griffin High School         93.392371          97.138965
# Hernandez High School       66.752967          80.862999
# Holden High School          92.505855          96.252927
# Huang High School           65.683922          81.316421
# Johnson High School         66.057551          81.222432
# Pena High School            94.594595          95.945946
# Rodriguez High School       66.366592          80.220055
# Shelton High School         93.867121          95.854628
# Thomas High School          93.272171          97.308869
# Wilson High School          93.867718          96.539641
# Wright High School          93.333333          96.611111
#
#                       % Overall Passing Rate Spending Ranges (Per Student)
# Bailey High School                   overall                      $615-645
# Cabrera High School                  overall                         <$585
# Figueroa High School                 overall                      $615-645
# Ford High School                     overall                      $615-645
# Griffin High School                  overall                      $615-645
# Hernandez High School                overall                      $645-675
# Holden High School                   overall                         <$585
# Huang High School                    overall                      $645-675
# Johnson High School                  overall                      $645-675
# Pena High School                     overall                      $585-615
# Rodriguez High School                overall                      $615-645
# Shelton High School                  overall                      $585-615
# Thomas High School                   overall                      $615-645
# Wilson High School                   overall                         <$585
# Wright High School                   overall                         <$585

# %%
#use groupby method based on school spending

by_spending =scores_by_sch.groupby(["Spending Ranges (Per Student)"])
by_spending.mean()
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-615                                83.599686              83.885211
# $615-645                                79.079225              81.891436
# $645-675                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-615                            94.230858          95.900287
# $615-645                            75.668212          86.106569
# $645-675                            66.164813          81.133951

# %%
# using the school size instead of the school spending and use the groupby method
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
type("School Size")
# Out:
# str

# %%
scores_by_sch["School Size"]=pd.cut(school_summery_df["Total Students"],size_bins , labels=group_names)
scores_by_sch.head()
# Out:
#                       Average Math Score  Average Reading Score  \
# Bailey High School             77.048432              81.033963
# Cabrera High School            83.061895              83.975780
# Figueroa High School           76.711767              81.158020
# Ford High School               77.102592              80.746258
# Griffin High School            83.351499              83.816757
#
#                       % Passing Math  % Passing Reading  \
# Bailey High School         66.680064          81.933280
# Cabrera High School        94.133477          97.039828
# Figueroa High School       65.988471          80.739234
# Ford High School           68.309602          79.299014
# Griffin High School        93.392371          97.138965
#
#                      % Overall Passing Rate Spending Ranges (Per Student)  \
# Bailey High School                  overall                      $615-645
# Cabrera High School                 overall                         <$585
# Figueroa High School                overall                      $615-645
# Ford High School                    overall                      $615-645
# Griffin High School                 overall                      $615-645
#
#                              School Size
# Bailey High School     Large (2000-5000)
# Cabrera High School   Medium (1000-2000)
# Figueroa High School   Large (2000-5000)
# Ford High School       Large (2000-5000)
# Griffin High School   Medium (1000-2000)

# %%
by_schSize = scores_by_sch.groupby(["School Size"])
by_schSize.mean()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading
# School Size
# Small (<1000)               96.099437
# Medium (1000-2000)          96.790680
# Large (2000-5000)           82.766634

# %%
# same method but group by school type
scores_by_type= school_summery_df.drop(columns=["Total Students","Total School Budget", "Per Student Budget"])
scores_by_type.head()
# Out:
#                      School Type  Average Math Score  Average Reading Score  \
# Bailey High School      District           77.048432              81.033963
# Cabrera High School      Charter           83.061895              83.975780
# Figueroa High School    District           76.711767              81.158020
# Ford High School        District           77.102592              80.746258
# Griffin High School      Charter           83.351499              83.816757
#
#                       % Passing Math  % Passing Reading  \
# Bailey High School         66.680064          81.933280
# Cabrera High School        94.133477          97.039828
# Figueroa High School       65.988471          80.739234
# Ford High School           68.309602          79.299014
# Griffin High School        93.392371          97.138965
#
#                      % Overall Passing Rate Spending Ranges (Per Student)
# Bailey High School                  overall                      $615-645
# Cabrera High School                 overall                         <$585
# Figueroa High School                overall                      $615-645
# Ford High School                    overall                      $615-645
# Griffin High School                 overall                      $615-645

# %%
by_schType = scores_by_type.groupby(["School Type"])

# %%
by_schType.mean()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading
# School Type
# Charter              96.586489
# District             80.799062

# %%
#use the file text method to write a conclusion
text_one="Charter Schools appear to have higher scores in all subjects"
text_two="Schools with smaller size have been shown to have higher passing rate, from observation less students give teachers more direct communication and allows instructors to more insight on students development"

# %%
print(text_one)
print(text_two)
# Out:
# Charter Schools appear to have higher scores in all subjects
# Schools with smaller size have been shown to have higher passing rate, from observation less students give teachers more direct communication and allows instructors to more insight on students development
